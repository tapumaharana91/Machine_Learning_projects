# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the dataset**

# %%
df=pd.read_csv('C://Users//ASUS//Downloads//Data Analysis Projects//House Price Prediction//ParisHousing.csv')

# %%
df.head(10)
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
# 5         39223             36        0        1      17     39489
# 6         58682             10        1        1      99      6450
# 7         86929            100        1        0      11     98155
# 8         51522              3        0        0      61      9047
# 9         39686             42        0        0      15     71019
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# ...

# %%
df.tail(10)
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 9990          5537             65        0        1      24      5808
# 9991         96173             12        1        0      36     36812
# 9992         33545             55        0        1      79      8288
# 9993           341             83        0        0       8      1960
# 9994         21514              5        0        1      11     91373
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 9990              8              6  2012           0                  1
# ...

# %%
df.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 17)

# %% [markdown]
# **Data Preprocessing**

# %%
obj = (df.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:",len(object_cols))

int_ = (df.dtypes == 'int64')
num_cols = list(int_[int_].index)
print("Integer variables:",len(num_cols))

fl = (df.dtypes == 'float64')
fl_cols = list(fl[fl].index)
print("Float variables:",len(fl_cols))
# Out:
# Categorical variables: 0
# Integer variables: 16
# Float variables: 1

# %%
plt.figure(figsize=(12,6))
corr=df.corr()
sns.heatmap(corr,
            fmt='.2f',
            cmap='viridis',
            linewidth=1,
            annot=True,
           )
# Out:
# <Axes: >

# %% [markdown]
# **Data Visualization**

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# 1. Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=50, kde=True)
plt.title('Price Distribution of Houses')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# 2. Relationship between House Size and Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['squareMeters'], y=df['price'])
plt.title('Relationship between House Size and Price')
plt.xlabel('Square Meters')
plt.ylabel('Price')
plt.show()

# 3. Impact of Having a Pool on Price
plt.figure(figsize=(10, 6))
sns.boxplot(x='hasPool', y='price', data=df)
plt.title('Impact of Having a Pool on Price')
plt.xlabel('Has Pool')
plt.ylabel('Price')
plt.show()

# 4. Number of Rooms vs. Price
plt.figure(figsize=(10, 6))
sns.boxplot(x='numberOfRooms', y='price', data=df)
plt.title('Number of Rooms vs. Price')
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# 5. Distribution of Houses by Year Built
plt.figure(figsize=(10, 6))
sns.histplot(df['made'], bins=50, kde=True)
plt.title('Distribution of Houses by Year Built')
plt.xlabel('Year Built')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 6. Effect of Yard Presence on Price
plt.figure(figsize=(10, 6))
sns.boxplot(x='hasYard', y='price', data=df)
plt.title('Effect of Yard Presence on Price')
plt.xlabel('Has Yard')
plt.ylabel('Price')
plt.show()

# 7. Comparison of Prices for New vs. Old Houses
plt.figure(figsize=(10, 6))
sns.boxplot(x='isNewBuilt', y='price', data=df)
plt.title('Comparison of Prices for New vs. Old Houses')
plt.xlabel('Is New Built')
plt.ylabel('Price')
plt.show()

# 8. Influence of City Part Range on House Prices
plt.figure(figsize=(10, 6))
sns.boxplot(x='cityPartRange', y='price', data=df)
plt.title('Influence of City Part Range on House Prices')
plt.xlabel('City Part Range')
plt.ylabel('Price')
plt.show()

# 9. Relationship between Number of Previous Owners and Price
plt.figure(figsize=(10, 6))
sns.boxplot(x='numPrevOwners', y='price', data=df)
plt.title('Relationship between Number of Previous Owners and Price')
plt.xlabel('Number of Previous Owners')
plt.ylabel('Price')
plt.show()

# %%
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %% [markdown]
# **Feature Selection**

# %%
x=df.drop(['price'],axis=1)
y=df['price']

# %% [markdown]
# **Model Training and Testing**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
import numpy as np

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=0)

# %% [markdown]
# **SUPPORT VECTOR MACHINE**

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error

model_SVR = svm.SVR()
model_SVR.fit(x_train,y_train)
y_pred = model_SVR.predict(x_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"R-squared: {r2}")
print(f'Mean Absolute Error: {mae}')
print("Mean Absolute Percentage Error:",mean_absolute_percentage_error(y_test, y_pred))
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R-squared: -0.00022670802397950496
# Mean Absolute Error: 2448574.9168864964
# Mean Absolute Percentage Error: 2.4748802595931076
# Mean Squared Error: 8040051810613.407
# Root Mean Squared Error: 2835498.511834102

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(x_train, y_train)
y_pred = model_RFR.predict(x_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"R-squared: {r2}")
print(f'Mean Absolute Error: {mae}')
print("Mean Absolute Percentage Error:",mean_absolute_percentage_error(y_test, y_pred))
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R-squared: 0.9999977784118346
# Mean Absolute Error: 3385.3767750000325
# Mean Absolute Percentage Error: 0.002049520609666083
# Mean Squared Error: 17857635.482334033
# Root Mean Squared Error: 4225.829561439273

# %% [markdown]
# **LINEAR REGRESSION**

# %%
#Optimal Model

from sklearn.linear_model import LinearRegression

model_LL=LinearRegression()
model_LL.fit(x_train,y_train)
y_pred=model_LL.predict(x_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"R-squared: {r2}")
print(f'Mean Absolute Error: {mae}')
print("Mean Absolute Percentage Error:",mean_absolute_percentage_error(y_test, y_pred))
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R-squared: 0.999999566785081
# Mean Absolute Error: 1442.0677199315064
# Mean Absolute Percentage Error: 0.0008178933842599458
# Mean Squared Error: 3482280.933127993
# Root Mean Squared Error: 1866.0870647233994

# %% [markdown]
# **CATBOOST**

# %%
from catboost import CatBoostRegressor

cb_model=CatBoostRegressor()
cb_model.fit(x_train,y_train)
y_pred=cb_model.predict(x_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"R-squared: {r2}")
print(f'Mean Absolute Error: {mae}')
print("Mean Absolute Percentage Error:",mean_absolute_percentage_error(y_test, y_pred))
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Learning rate set to 0.056868
# 0:	learn: 2732834.8126792	total: 17.2ms	remaining: 17.2s
# 1:	learn: 2586467.3321063	total: 68.6ms	remaining: 34.2s
# 2:	learn: 2447821.3795260	total: 82.9ms	remaining: 27.5s
# 3:	learn: 2316766.6449842	total: 203ms	remaining: 50.6s
# 4:	learn: 2191075.9637336	total: 216ms	remaining: 43s
# 5:	learn: 2077921.5545061	total: 229ms	remaining: 38s
# 6:	learn: 1968514.0785461	total: 264ms	remaining: 37.4s
# 7:	learn: 1861552.6035905	total: 308ms	remaining: 38.2s
# 8:	learn: 1765344.3959016	total: 324ms	remaining: 35.7s
# 9:	learn: 1675246.4925642	total: 337ms	remaining: 33.4s
# 10:	learn: 1586703.0526857	total: 356ms	remaining: 32s
# 11:	learn: 1506816.0780278	total: 374ms	remaining: 30.8s
# 12:	learn: 1424612.4703565	total: 386ms	remaining: 29.3s
# 13:	learn: 1350236.7164886	total: 395ms	remaining: 27.8s
# 14:	learn: 1279970.4843238	total: 403ms	remaining: 26.4s
# 15:	learn: 1213055.9249542	total: 411ms	remaining: 25.3s
# ...

# %% [markdown]
# **Applying Prediction**

# %%
# New Prediction with Linear Regression 

new_square_meters = 75523
new_number_of_rooms = 4  
new_has_yard = 1  
new_has_pool = 0  
new_floors = 2 
new_city_code = 9373 
new_city_part_range = 3 
new_num_prev_owners = 1  
new_construction_year = 2020  
new_is_new_built = 1  
new_has_storm_protector = 1  
new_basement = 0  
new_attic = 1  
new_garage = 1 
new_has_storage_room = 1  
new_has_guest_room = 0 

new_house_features = pd.DataFrame({
    'squareMeters': [new_square_meters],
    'numberOfRooms': [new_number_of_rooms],
    'hasYard': [new_has_yard],
    'hasPool': [new_has_pool],
    'floors': [new_floors],
    'cityCode': [new_city_code],
    'cityPartRange': [new_city_part_range],
    'numPrevOwners': [new_num_prev_owners],
    'made': [new_construction_year],
    'isNewBuilt': [new_is_new_built],
    'hasStormProtector': [new_has_storm_protector],
    'basement': [new_basement],
    'attic': [new_attic],
    'garage': [new_garage],
    'hasStorageRoom': [new_has_storage_room],
    'hasGuestRoom': [new_has_guest_room],
    
})

predicted_price =model_LL.predict(new_house_features)
print(f"the Predicted Price: Rs {predicted_price[0]:.2f}")
# Out:
# the Predicted Price: Rs 7556164.07

# %%
plt.scatter(y_test, y_pred, color='red')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Prices (Linear Regression)')
plt.show()
